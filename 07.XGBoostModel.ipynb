# %%
from xgboost import XGBRegressor

import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, KFold

DATA_DIR = "D:/Machine-Learning/HousePrice prediction/data"
x = pd.read_csv(f"{DATA_DIR}/x.csv")
y = pd.read_csv(f"{DATA_DIR}/y.csv").squeeze()  # Convert DataFrame to Series

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.01,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# The mean squared error (MSE) on test set: 160761967765.9897
# 0.9539810562938847

# %%
import numpy as np

rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 400951.3284252712
